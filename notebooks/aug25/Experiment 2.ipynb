# %% [markdown]
# # True Data #
# For this experiment, the following true E.coli genomic data were used:
# #### Reference genome ####
# * [_Escherichia coli_ str. K-12 substr. MG1655, complete genome](http://www.ncbi.nlm.nih.gov/nuccore/NC_000913)
#
# #### PacBio Long Reads ####
# * [_E.coli_ K12 MG1655 CLR Reads from Pacific Biosciences DevNet](https://github.com/PacificBiosciences/DevNet/wiki/E%20coli%20K12%20MG1655%20Hybrid%20Assembly)
# * [_E.coli_ K12 MG1655 CCS Reads from Pacific Biosciences Devnet](https://github.com/PacificBiosciences/DevNet/wiki/E%20coli%20K12%20MG1655%20Hybrid%20Assembly)
# * [Pacific Biosciences Model Organism Genome Sequencing of _E.coli_ P5C3 - SRR1284073](http://www.ncbi.nlm.nih.gov/sra/?term=SRR1284073)
#
# ## Analyses ##
# Length distribution histograms and length-accuracy scatterplots were created for each dataset and mean identities were also found.
#
# |  Dataset   | Mean Identity |
# | :-------:  | :-----------: |
# | CLR        | 1323          |
# | CCS        | 475           |
# | SRR1284073 | 3555          |
#
# ### Length Distributions ###
#
# #### CLR ####
# ![CLR Length Distribution](ecoli_real/length_distributions/PacBio_10kb_CLR_length_dist.png)
#
# #### CCS ####
# ![CCS Length Distribution](ecoli_real/length_distributions/PacBio_2kb_CCS_500bp_length_dist.png)
#
# #### SRR1284073 ####
# ![SRR1284073 Length Distribution](ecoli_real/length_distributions/SRR1284073_length_dist.png)
#
# ### Length-Accuracy Scatterplots ###
#
# #### CLR ####
# ![CLR Length-Accuracy Scatterplots](ecoli_real/length_accuracy/PacBio_10kb_CLR_length_accuracy_scatter.png)
#
# #### CCS ####
# ![CCS Length-Accuracy Scatterplots](ecoli_real/length_accuracy/PacBio_2kb_CCS_length_accuracy_scatter.png)
#
# #### SRR1284073 ####
# ![SRR1284073 Length-Accuracy Scatterplots](ecoli_real/length_accuracy/SRR1284073_length_accuracy_scatter.png)
#
# # Simulated Data #
# PacBio long reads were simulated using SimLoRD. Two types of reads were simulated: CLR reads (e.g. maximum number of passes over each each read was set to 1) and CCS reads (e.g. maximum number of passes over each read was set to 40). For each type of read, datasets of long reads with coverages 10, 20, 50 and 75 were simulated.
#
# ## CLR Analyses ##
# Length distribution histograms, length-accuracy scatterplots, and length - true error rate scatter plots were created for each dataset and mean identities were also found.
#
# |  Coverage   | Mean Identity |
# | :--------:  | :-----------: |
# | 10          | 2884          |
# | 20          | 2873          |
# | 50          | 2897          |
# | 75          | 2879          |
#
# ### Length Distributions ###
#
# #### Coverage 10 ####
# ![Coverage 10 Length Distribution](ecoli_clr/length_distributions/long-d10.png)
#
# #### Coverage 20 ####
# ![Coverage 20 Length Distribution](ecoli_clr/length_distributions/long-d20.png)
#
# #### Coverage 50 ####
# ![Coverage 50 Length Distribution](ecoli_clr/length_distributions/long-d50.png)
#
# #### Coverage 75 ####
# ![Coverage 75 Length Distribution](ecoli_clr/length_distributions/long-d75.png)
#
# ### Length - Accuracy Scatterplots ###
#
# #### Coverage 10 ####
# ![Coverage 10 Length Accuracy Scatterplot](ecoli_clr/length_accuracy/ecoli-long-d10_length_accuracy_scatter.png)
#
# #### Coverage 20 ####
# ![Coverage 20 Length Accuracy Scatterplot](ecoli_clr/length_accuracy/ecoli-long-d20_length_accuracy_scatter.png)
#
# #### Coverage 50 ####
# ![Coverage 50 Length Accuracy Scatterplot](ecoli_clr/length_accuracy/ecoli-long-d50_length_accuracy_scatter.png)
#
# #### Coverage 75 ####
# ![Coverage 75 Length Accuracy Scatterplot](ecoli_clr/length_accuracy/ecoli-long-d75_length_accuracy_scatter.png)
#
# ### Length - True Error Rate Scatterplots ###
#
# #### Coverage 10 ####
# ![Coverage 10 Length - True Error Rate Scatter](ecoli_clr/error_rate_scatter/ecoli-long-d10_error_rate_scatter.png)
#
# #### Coverage 20 ####
# ![Coverage 20 Length - True Error Rate Scatter](ecoli_clr/error_rate_scatter/ecoli-long-d20_error_rate_scatter.png)
#
# #### Coverage 50 ####
# ![Coverage 50 Length - True Error Rate Scatter](ecoli_clr/error_rate_scatter/ecoli-long-d50_error_rate_scatter.png)
#
# #### Coverage 75 ####
# ![Coverage 75 Length - True Error Rate Scatter](ecoli_clr/error_rate_scatter/ecoli-long-d75_error_rate_scatter.png)
